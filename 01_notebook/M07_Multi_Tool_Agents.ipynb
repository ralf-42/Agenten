# %% [markdown]
# <p><font size="6" color='grey'> <b>
# KI-Agenten. Verstehen. Anwenden. Gestalten.
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Multi-Tool Agents
# </b></font> </br></p>
#
# ---

# %%
#@title 🔧 Umgebung einrichten{ display-mode: "form" }
# !uv pip install --system -q git+https://github.com/ralf-42/GenAI.git#subdirectory=04_modul
from genai_lib.utilities import (
    check_environment,
    get_ipinfo,
    setup_api_keys,
    mprint,
    install_packages,
    mermaid,
    get_model_profile,
    extract_thinking,
    load_prompt
)
setup_api_keys(['OPENAI_API_KEY'], create_globals=False)
print()
check_environment()
print()
get_ipinfo()

# %% [markdown]
# # 1 | Übersicht
# ---
#
# [Inhalt von Kapitel 1]

# %% [markdown]
# # 2 | Agent mit 3-4 Tools
# ---
#
# [Inhalt von Kapitel 2]

# %% [markdown]
# # 3 | Komplexe Multi-Step Aufgaben
# ---
#
# [Inhalt von Kapitel 3]

# %% [markdown]
# # 4 | Agent-Debugging mit LangSmith
# ---
#
# [Inhalt von Kapitel 4]

# %% [markdown]
# # 5 | Warum wählt der Agent Tool X?
# ---
#
# [Inhalt von Kapitel 5]

# %% [markdown]
# # 6 | Error Handling & Fallbacks
#
# - Typische Fehler: Tool-Timeout, leere Tool-Response, Schema-Fehler
# - Strategien: Retry, Timeout-Limits, Fallback-Antworten
# - Ziel: Agent bleibt robust statt still zu scheitern

# %% [markdown]
# # A | Aufgabe
# ---
#
# Die Aufgabestellungen unten bieten Anregungen, Sie können aber auch gerne eine andere Herausforderung angehen.
#
# <p><font color='black' size="5">
# [Aufgabentitel]
# </font></p>
#
# [Aufgabenbeschreibung]
#
# **[Optionale Teilaufgaben]:**
# - Teilaufgabe 1
# - Teilaufgabe 2
