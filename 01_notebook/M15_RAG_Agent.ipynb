# %% [markdown]
# <p><font size="6" color='grey'> <b>
# KI-Agenten. Planen. Handeln. Prüfen.
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# RAG-Agent
# </b></font> </br></p>
#
# ---

# %% [markdown]
# **Beitrag zum Leitprojekt:** Hier wird das Evidence Tool zu einer Fähigkeit unter mehreren — der Meeting- & Research-Briefing-Agent **plant** jetzt selbst, ob eine Frage RAG braucht, reines Modellwissen ausreicht oder ein anderes Tool gefragt ist (siehe Kapitel 4). Der Grenzfall-Test unten zeigt zugleich **Prüfen** in Aktion: Fehlt Evidenz, antwortet der Agent mit "Nicht im Korpus" statt zu spekulieren.

# %%
#@title 🛠️ Umgebung einrichten{ display-mode: "form" }
# !uv pip install --system -q git+https://github.com/ralf-42/Agenten.git#subdirectory=04_modul

import os
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"]    = "M15-RAG-Agent"
os.environ["LANGSMITH_ENDPOINT"]   = "https://eu.api.smith.langchain.com"

from genai_lib.utilities import (
    check_environment,
    get_ipinfo,
    setup_api_keys,
    mprint,
    install_packages,
    mermaid,
    get_model_profile,
    extract_thinking,
    load_prompt,
    show_trace
)

setup_api_keys(['OPENAI_API_KEY', 'LANGSMITH_API_KEY'], create_globals=False)
print()
check_environment()
print()
get_ipinfo()

# Modell-Konfiguration — Rollen als Konstanten
from genai_lib.model_config import BASELINE, ROUTER, JUDGE, PLANNER, WORKER, WORKER_PREMIUM, CODING, EMBEDDINGS
# Out:
# ✓ OPENAI_API_KEY erfolgreich gesetzt
# ✓ LANGSMITH_API_KEY erfolgreich gesetzt
#
# Python Version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
# Installierte LangChain- und LangGraph-Bibliotheken:
# langchain                                1.2.15
# langchain-chroma                         1.1.0
# langchain-classic                        1.0.4
# langchain-community                      0.4.1
# langchain-core                           1.3.1
# langchain-ollama                         1.1.0
# langchain-openai                         1.2.0
# langchain-text-splitters                 1.1.2
# langgraph                                1.1.9
# langgraph-checkpoint                     4.0.2
# langgraph-prebuilt                       1.0.10
# langgraph-sdk                            0.3.13
#
# IP-Adresse: 104.196.134.156
# Hostname: 156.134.196.104.bc.googleusercontent.com
# Stadt: North Charleston
# Region: South Carolina
# Land: US
# Koordinaten: 32.8546,-79.9748
# ...

# %%
#@title 📦 Installationen { display-mode: "form" }
install_packages([
    ('pypdf', 'pypdf'),
])
# Out:
# 🔄 Installiere pypdf...
# ✅ pypdf erfolgreich installiert und importiert

# %%
#@title 📂 Meeting-Briefing-Korpus laden { display-mode: "form" }
import shutil
from genai_lib.utilities import copy_from_github

KORPUS_QUELLE = "ralf-42/Agenten/02_daten/01_text/korpus_meeting_briefing"
KORPUS_MASKE = "*.pdf"
KORPUS_TARGET = "/content/files"

shutil.rmtree(KORPUS_TARGET, ignore_errors=True)
copy_from_github(
    source=KORPUS_QUELLE,
    target=KORPUS_TARGET,
    mask=KORPUS_MASKE,
)

# %% [markdown]
# # 1 | Übersicht
# ---

# %% [markdown]
# In *RAG-Chain mit LangChain* wurde eine **RAG-Chain** gebaut: deterministisch, mit linearem Ablauf.
# Jetzt folgt der nächste Schritt: **RAG als Tool für einen Agenten**.
#
# **Von der Chain zum Agent**
#
# | Merkmal | RAG-Chain (M14) | RAG-Agent (M15) |
# |---------|----------------|----------------|
# | Ablauf | Immer: Retrieve → Generate | Nur bei Bedarf: Agent entscheidet |
# | RAG-Nutzung | Immer aktiv | Tool, das der Agent auswählt |
# | Weiteres Wissen | Nur Vektordatenbank | Modellwissen + RAG + weitere Tools |
# | Flexibilität | Niedrig | Hoch |
# | Komplexität | Gering | Mittel |
#
# **Was entsteht**
#
# Ein Agenten-System mit **RAG als einem von mehreren Tools**:
# - `suche_wissensdatenbank` – RAG-Tool für belegbare Fragen zum Meeting-Briefing-Korpus
# - `erklaere_konzept` – Direktes Modellwissen für allgemeine Erklärungen
# - `schaetze_tokens` – Einfaches Berechnungstool für Kontextkosten

# %% [markdown]
# # 2 | RAG als Tool
# ---

# %% [markdown]
# Ein **RAG-Tool** ist eine normale LangChain-Tool-Funktion, die intern ChromaDB abfragt. Der Agent entscheidet, ob diese Quelle nötig ist.
#
#
# Der Index-Aufbau ist hier Voraussetzung, nicht das Lernziel. Der Fokus liegt auf Tool-Definition, Tool-Wahl und Quellen-Grenzen des Agenten.

# %% [markdown]
# <p><font color='black' size="5">
# Design-Prinzipien für RAG-Tools
# </font></p>
#
#
# | Prinzip | Beschreibung |
# |---------|-------------|
# | **Klarer Name** | Name sagt dem Agenten, wann das Tool zu nutzen ist |
# | **Präzise Beschreibung** | Docstring erklärt genau, welche Fragen das Tool beantwortet |
# | **Fehlerbehandlung** | Gibt lesbaren Text zurück, kein `raise` |
# | **Formatierte Ausgabe** | Gibt Quellen + Antwort zurück |

# %%
from pathlib import Path

from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.documents import Document
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langchain_openai import OpenAIEmbeddings

from genai_lib.model_config import WORKER
# LLM und Embeddings
llm = init_chat_model(WORKER)
embeddings = OpenAIEmbeddings(model=EMBEDDINGS)

# %% [markdown]
# 📦 **Prerequisite-Hinweis zu `genai_lib.briefing_rag`:** Der hier selbst gebaute Code (PDF-Laden, Chunking, Chroma-Aufbau, `suche_wissensdatenbank`) ist zusätzlich als wiederverwendbares Modul verfügbar (`genai_lib.briefing_rag`, installierbar via `git+https://github.com/ralf-42/Agenten.git#subdirectory=04_modul`). Für dieses Notebook dient der Aufbau nur dazu, ein belastbares RAG-Tool zu haben. Die Collection liegt dauerhaft auf Google Drive (`Agenten/02_daten/05_sonstiges/chroma_briefing`), damit spätere Module wie M26 und M38 sie direkt importieren können. M23 bleibt bewusst synthetisch/in-memory, M29 nutzt eine isolierte Experiment-Collection.

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
def load_pdf_documents(directory_path: str):
    """Lädt alle PDF-Seiten aus einem Verzeichnis."""
    documents = []
    for pdf_path in sorted(Path(directory_path).glob("*.pdf")):
        try:
            loader = PyPDFLoader(str(pdf_path))
            documents.extend(loader.load())
        except Exception as exc:
            print(f"  ⚠ {pdf_path.name} übersprungen: {exc}")
    return documents


def split_documents_by_characters(documents, chunk_size=300, chunk_overlap=30):
    """Teilt Dokumentseiten in überlappende Zeichen-Chunks."""
    chunks = []
    step = max(1, chunk_size - chunk_overlap)
    for doc in documents:
        text = doc.page_content or ""
        for chunk_index, start in enumerate(range(0, len(text), step)):
            chunk_text = text[start:start + chunk_size].strip()
            if not chunk_text:
                continue
            metadata = dict(doc.metadata)
            metadata["chunk_index"] = chunk_index
            chunks.append(Document(page_content=chunk_text, metadata=metadata))
    return chunks


# Dokumente laden und splitten
dokumente_raw = load_pdf_documents(KORPUS_TARGET)
chunks = split_documents_by_characters(
    dokumente_raw,
    chunk_size=300,
    chunk_overlap=30,
)

# ChromaDB aufbauen (persistent, auf Google Drive) — mit Batching für große Korpora
BATCH_SIZE = 500
vectorstore = Chroma(
    collection_name="meeting_briefing_korpus_m14",
    embedding_function=embeddings,
    persist_directory="/content/drive/MyDrive/Agenten/02_daten/05_sonstiges/chroma_briefing",
)

count_vorher = vectorstore._collection.count()
if count_vorher == 0:
    for start in range(0, len(chunks), BATCH_SIZE):
        batch = chunks[start:start + BATCH_SIZE]
        vectorstore.add_documents(batch)
        ende = min(start + BATCH_SIZE, len(chunks))
        print(f"  Batch {start // BATCH_SIZE + 1}: {ende}/{len(chunks)} Chunks indexiert")
else:
    print(f"Collection hat bereits {count_vorher} Einträge — kein erneutes Indexieren")

print(f"Geladene PDF-Seiten: {len(dokumente_raw)}")
print(f"Chunks verfügbar:    {len(chunks)}")
print(f"Collection-Größe:    {vectorstore._collection.count()}")

# %% [markdown]
# # 3 | RAG-Agent bauen
# ---

# %%
from genai_lib.model_config import WORKER
@tool
def suche_wissensdatenbank(frage: str) -> str:
    """Durchsucht den Meeting- & Projekt-Korpus zu Entscheidungen, Risiken und offenen Punkten
    sowie die Fachartikel zu RAG, Retrieval, Evaluation und Agenten.
    Geeignet für belegbare Fragen zu Projekt Kompass und Fragen nach Quellen.
    """
    try:
        ergebnisse = vectorstore.similarity_search_with_score(frage, k=3)
        if not ergebnisse:
            return "Nicht im Korpus. Keine relevanten Informationen gefunden."

        antwort_teile = []
        for doc, score in ergebnisse:
            quelle = doc.metadata.get("source", "unbekannt").split("/")[-1]
            ausschnitt = doc.page_content.replace("\n", " ")[:700]
            antwort_teile.append(
                f"Quelle: {quelle}\n"
                f"Score: {score:.4f}\n"
                f"Ausschnitt: {ausschnitt}"
            )

        return "\n\n---\n\n".join(antwort_teile)
    except Exception as exc:
        return f"Fehler bei der Datenbanksuche: {exc}"


@tool
def erklaere_konzept(konzept: str) -> str:
    """Erklärt ein allgemeines KI- oder Informatik-Konzept kurz und verständlich.
    Geeignet für Grundlagenfragen ohne zwingenden Bezug zum Meeting-Briefing-Korpus.
    """
    erklaer_llm = init_chat_model(WORKER)
    prompt = f"Erkläre das Konzept '{konzept}' in 2-3 Sätzen für einen Einstiegskurs."
    return erklaer_llm.invoke(prompt).content


@tool
def schaetze_tokens(text: str, modell: str = "gpt-5.4-mini") -> str:
    """Schätzt Tokenzahl und grobe Eingabekosten für einen Text."""
    zeichen = len(text)
    tokens_grob = zeichen // 3
    kosten_pro_1000 = 0.005
    kosten = (tokens_grob / 1000) * kosten_pro_1000
    return (
        f"Text: {zeichen} Zeichen\n"
        f"Geschätzte Tokens: ~{tokens_grob} (Faustregel: 3 Zeichen/Token)\n"
        f"Geschätzte Kosten ({modell}): ~${kosten:.6f}"
    )


tools = [suche_wissensdatenbank, erklaere_konzept, schaetze_tokens]
print(f"Tools definiert: {[t.name for t in tools]}")

# %%
# RAG-Agent erstellen
system_prompt = load_prompt("https://github.com/ralf-42/Agenten/blob/main/05_prompt/m14_rag_agent_system_prompt.md", mode="S")

rag_agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt=system_prompt,
    debug=False
)

print("RAG-Agent erstellt")
print(f"Tools: {[t.name for t in tools]}")
# Out:
# RAG-Agent erstellt
# Tools: ['suche_wissensdatenbank', 'erklaere_konzept', 'schaetze_tokens']

# %% [markdown]
# # 4 | Wann RAG, wann eigenes Wissen?
# ---

# %% [markdown]
# Der Agent entscheidet selbst, welches Tool er nutzt – aber wie trifft er diese Entscheidung?
#
# **Entscheidungslogik**
#
# Der Agent wählt das Tool basierend auf **drei Faktoren**:
#
# 1. **Tool-Name** – Sprechende Namen helfen: `suche_wissensdatenbank` vs. `erklaere_konzept`
# 2. **Docstring** – Präzise Beschreibung, wann das Tool einzusetzen ist
# 3. **Kontext der Frage** – Spezifisch (→ RAG) vs. allgemein (→ eigenes Wissen)

# %%
#@markdown   <p><font size="4" color='green'>  flowchart</font> </br></p>

diagram = '''
# %%{init: {'theme':'forest'}}%%
flowchart TD
    FRAGE["❓ Nutzerfrage"]

    FRAGE --> SPEZ{{"Research-Frage?
(RAG, Retrieval,
Evaluation, Agenten)"}}
    SPEZ -->|"Ja"| RAG["📚 suche_wissensdatenbank()
ChromaDB Retrieval"]
    SPEZ -->|"Nein"| ALLG{{"Allgemeines
Konzept?"}}

    ALLG -->|"Ja"| LLM["🧠 erklaere_konzept()
Modellwissen"]
    ALLG -->|"Nein"| CALC{{"Berechnung
nötig?"}}

    CALC -->|"Ja"| TOK["🔢 schaetze_tokens()
Faustregel"]
    CALC -->|"Nein"| DIRECT["💬 Direkte Antwort"]

    RAG --> ANS["Antwort"]
    LLM --> ANS
    TOK --> ANS
    DIRECT --> ANS
'''

mermaid(diagram, width=850)
# Out:
# <div id="mermaid-0c5a1914" style="width:850px"><pre class="mermaid">
# %%{init: {'theme':'forest'}}%%
# flowchart TD
#     FRAGE["❓ Nutzerfrage"]
#
#     FRAGE --> SPEZ{{"Research-Frage?
# (RAG, Retrieval,
# Evaluation, Agenten)"}}
#     SPEZ -->|"Ja"| RAG["📚 suche_wissensdatenbank()
# ChromaDB Retrieval"]
#     SPEZ -->|"Nein"| ALLG{{"Allgemeines
# Konzept?"}}
#
#     ALLG -->|"Ja"| LLM["🧠 erklaere_konzept()
# Modellwissen"]
#     ALLG -->|"Nein"| CALC{{"Berechnung
# nötig?"}}
#
#     CALC -->|"Ja"| TOK["🔢 schaetze_tokens()
# Faustregel"]
#     CALC -->|"Nein"| DIRECT["💬 Direkte Antwort"]
#
#     RAG --> ANS["Antwort"]
#     LLM --> ANS
#     TOK --> ANS
#     DIRECT --> ANS
# </pre></div>
# <script type="module">
#     // Mermaid einmalig laden und in window._mermaidLib cachen.
#     // Bei schnellem "Run All" vermeidet das Race Conditions durch parallele CDN-Requests.
#     if (!window._mermaidLib) {
# ...

# %%
# Test: Agent zeigt unterschiedliche Tool-Wahl
test_fragen = [
    # Erwartet: suche_wissensdatenbank
    "Wie unterscheidet sich naive RAG von advanced RAG?",
    # Erwartet: suche_wissensdatenbank
    "Warum kann irrelevanter Kontext bei RAG problematisch sein?",
    # Erwartet: erklaere_konzept oder direkte Antwort
    "Was ist ein Embedding-Vektor in der KI?",
    # Erwartet: schaetze_tokens
    "Schätze die Tokenzahl für diesen kurzen Beispieltext zur RAG-Evaluation.",
]

run_cfg = {"run_name": "M15-RAG-Agent-Tool-Wahl", "tags": ["rag-agent", "m15", "meeting-briefing-korpus"]}

toolwahl_ergebnisse = []
for frage in test_fragen:
    print(f"Frage: {frage}")
    ergebnis = rag_agent.invoke(
        {"messages": [HumanMessage(content=frage)]},
        config=run_cfg,
    )
    letzte_antwort = ergebnis["messages"][-1].content
    tool_calls = [m for m in ergebnis["messages"] if getattr(m, "type", None) == "tool"]
    toolwahl_ergebnisse.append({"frage": frage, "tool_calls": len(tool_calls), "antwort": letzte_antwort})
    print(f"Tool-Aufrufe: {len(tool_calls)}")
    print(f"Antwort: {letzte_antwort[:300]}...")
    print("-" * 60)
    print()

# %% [markdown]
# # 5 | End-to-End Testing
# ---

# %% [markdown]
# Ein gutes RAG-System braucht systematische Tests.
#
#
#
#
# | Testtyp | Was wird geprüft? | Methode |
# |---------|-------------------|--------|
# | **Retrieval-Test** | Werden relevante Dokumente gefunden? | Manuell prüfen |
# | **Antwortqualität** | Sind die Antworten korrekt? | Expected vs. Actual |
# | **Tool-Wahl** | Wählt der Agent das richtige Tool? | Trace analysieren |

# %%
# End-to-End Test: vollständiger Durchlauf
test_szenarien = [
    {
        "frage": "Wie unterscheidet sich naive RAG von advanced RAG?",
        "keywords": ["naive", "advanced", "RAG"],
    },
    {
        "frage": "Warum ist Evaluation bei RAG-Systemen wichtig?",
        "keywords": ["Evaluation", "RAG"],
    },
]

print("=== End-to-End Test ===\n")
run_cfg = {"run_name": "M15-E2E-Test", "tags": ["test", "m15", "meeting-briefing-korpus"]}

e2e_ergebnisse = []
for i, szenario in enumerate(test_szenarien):
    frage = szenario["frage"]
    print(f"Test {i+1}: {frage}")

    ergebnis = rag_agent.invoke(
        {"messages": [HumanMessage(content=frage)]},
        config=run_cfg,
    )

    antwort = ergebnis["messages"][-1].content
    treffer = sum(
        1 for wort in szenario["keywords"]
        if wort.lower() in antwort.lower()
    )
    gesamt = len(szenario["keywords"])
    status = "PASS" if treffer >= max(1, gesamt // 2) else "FAIL"
    e2e_ergebnisse.append({"frage": frage, "treffer": treffer, "gesamt": gesamt, "status": status})

    print(f"  Antwort: {antwort[:220]}...")
    print(f"  Schlüsselwörter: {treffer}/{gesamt} gefunden")
    print(f"  Status: {status}")
    print()

# %% [markdown]
# **Zusammenfassung: Wann was?**
#
# | Kriterium | RAG-Chain | RAG-Agent |
# |-----------|-----------|-----------|
# | Einfache Q&A | Ideal | Overhead |
# | Gemischte Fragen | Nur RAG | Flexibel |
# | Mehrere Tools | Komplex | Geeignet |
# | Nachvollziehbarkeit | Deterministisch | Trace nötig |
# | Einstieg | Empfohlen | Nachgelagert |
#
# **Empfehlung:** Mit RAG-Chain starten, bei Bedarf zum RAG-Agenten ausbauen.

# %% [markdown]
# # A | Aufgaben
# ---

# %% [markdown]
# <p><font color='darkblue' size="4">
# 📌 <b>Wichtig</b>
# </font></p>
#
# Die Aufgabenstellungen bieten Anregungen; alternative Herausforderungen sind möglich.
#
# **Hinweis zur Lösungshilfe:**
# > Generative KI kann als Unterstützung beim Lernen und Entwickeln genutzt werden. Bei Fehlermeldungen, Teilproblemen oder Code-Varianten kann zum Beispiel Gemini in Google Colab helfen.
# > <br>**Wichtig ist nur:** Die KI dient als Lern- und Entwicklungshilfe. Der Schwerpunkt des Kurses bleibt darauf, KI-Agenten selbst zu verstehen, aufzubauen und gezielt weiterzuentwickeln.

# %% [markdown]
# **Grundlagen**
# - Meeting-Briefing-Korpus als RAG-Tool für den Agenten verwenden.
# - `suche_wissensdatenbank` mit mindestens einer Frage aus dem Eval-Set testen.
# - Ergebnis mit Quelle und kurzem Ausschnitt anzeigen.
# - Fertigen Agenten in `mein_rag_agent` speichern.
#
# **✅ Erledigt wenn:** `mein_rag_agent.invoke(...)` gibt eine Antwort zurück und der Grundlagen-Selbstcheck läuft fehlerfrei.

# %%
# Grundlagen: vorhandenen RAG-Agenten für die Aufgabe verwenden
mein_rag_agent = rag_agent

grundlagen_frage = "Wie unterscheidet sich naive RAG von advanced RAG?"
grundlagen_ergebnis = mein_rag_agent.invoke(
    {"messages": [HumanMessage(content=grundlagen_frage)]},
    config={"run_name": "M15-Aufgabe-Grundlagen", "tags": ["m15", "grundlagen"]},
)
mprint(grundlagen_ergebnis["messages"][-1].content[:700])

# %%
# ✅ Selbstcheck Grundlagen
assert "mein_rag_agent" in globals(), "❌ mein_rag_agent fehlt."
assert hasattr(mein_rag_agent, "invoke"), (
    "❌ Kein invoke() – wurde der Agent mit create_agent() erstellt?"
)
assert "grundlagen_ergebnis" in globals(), "❌ grundlagen_ergebnis fehlt."

_antwort = grundlagen_ergebnis["messages"][-1].content
assert isinstance(_antwort, str) and len(_antwort) > 20, (
    "❌ Grundlagen-Antwort ist zu kurz."
)

print("✅ Grundlagen-Selbstcheck bestanden!")
# Out:
# ✅ Grundlagen-Selbstcheck bestanden!

# %% [markdown]
# **Aufbau**
# - Agenten mit drei Tools prüfen: Research-Suche, Konzept-Erklärung und Token-Schätzung.
# - Drei Fragen testen: eine Research-Frage, eine allgemeine Konzeptfrage, eine Berechnungsfrage.
# - Tool-Aufrufe und Antwortauszüge dokumentieren.
#
# **✅ Erledigt wenn:** Für mindestens 3 Fragen liegen Antworten vor; die Tool-Wahl ist in `toolwahl_ergebnisse` dokumentiert.

# %%
# Aufbau: drei Fragetypen mit demselben Agenten testen
aufbau_fragen = [
    "Welche Risiken oder offenen Punkte bleiben im Projekt Kompass?",
    "Was bedeutet Kontextfenster bei Sprachmodellen?",
    "Schätze die Tokenzahl für: Retrieval ergänzt den Prompt mit Quellen.",
]

toolwahl_ergebnisse = []
for frage in aufbau_fragen:
    ergebnis = mein_rag_agent.invoke(
        {"messages": [HumanMessage(content=frage)]},
        config={"run_name": "M15-Aufgabe-Aufbau", "tags": ["m15", "toolwahl"]},
    )
    antwort = ergebnis["messages"][-1].content
    tool_calls = [m for m in ergebnis["messages"] if getattr(m, "type", None) == "tool"]
    toolwahl_ergebnisse.append({"frage": frage, "tool_calls": len(tool_calls), "antwort": antwort})
    mprint(f"Frage: {frage}")
    mprint(f"Tool-Aufrufe: {len(tool_calls)}")
    mprint(f"Antwort: {antwort[:300]}...")
    mprint("---")

# %%
# ✅ Selbstcheck Aufbau
assert "toolwahl_ergebnisse" in globals(), "❌ toolwahl_ergebnisse fehlt."
assert isinstance(toolwahl_ergebnisse, list) and len(toolwahl_ergebnisse) >= 3, (
    "❌ toolwahl_ergebnisse muss mindestens 3 dokumentierte Fragen enthalten."
)
assert all("frage" in r and "antwort" in r and "tool_calls" in r for r in toolwahl_ergebnisse), (
    "❌ Jede Zeile braucht frage, antwort und tool_calls."
)
assert all(len(str(r["antwort"])) > 20 for r in toolwahl_ergebnisse), (
    "❌ Mindestens eine Antwort ist zu kurz."
)

print("✅ Aufbau-Selbstcheck bestanden!")
# Out:
# ✅ Aufbau-Selbstcheck bestanden!

# %% [markdown]
# **Vertiefung**
# - LangSmith-Test mit `run_name` und `tags` ergänzen.
# - Tool-Wahl für Research-Frage, Konzeptfrage und Out-of-Corpus-Frage vergleichen.
# - Fälle mit unerwarteter Tool-Wahl dokumentieren.
# - Beobachtung in `_tool_wahl_beobachtung` speichern.
#
# **✅ Erledigt wenn:** LangSmith enthält die Testläufe; `_tool_wahl_beobachtung` beschreibt mindestens eine Grenze der Tool-Wahl.

# %%
# Vertiefung: LangSmith-Analyse der Tool-Wahl
grenzfall_frage = "Welche Frage liegt außerhalb des Projektkorpus?"
result = mein_rag_agent.invoke(
    {"messages": [HumanMessage(content=grenzfall_frage)]},
    config={"run_name": "M15-Aufgabe-Grenzfall", "tags": ["m15", "grenzfall"]},
)
print(result["messages"][-1].content[:700])

_tool_wahl_beobachtung = (
    "Bei Out-of-Corpus-Fragen kann der Agent trotzdem das Research-Tool aufrufen, "
    "weil die Frage formal wie eine Fachfrage wirkt. Entscheidend ist dann, dass "
    "Prompt und Tool-Ausgabe fehlende Evidenz klar als 'Nicht im Korpus' behandeln."
)

# %%
# ✅ Selbstcheck Vertiefung
assert "_tool_wahl_beobachtung" in globals(), (
    "❌ _tool_wahl_beobachtung fehlt."
)
assert isinstance(_tool_wahl_beobachtung, str) and len(_tool_wahl_beobachtung) >= 80, (
    "❌ _tool_wahl_beobachtung ist zu kurz."
)
assert "result" in globals(), "❌ Grenzfall-result fehlt."
_grenzfall_antwort = result["messages"][-1].content
_grenzfall_text = str(_grenzfall_antwort).strip().lower()
assert isinstance(_grenzfall_antwort, str) and "nicht im korpus" in _grenzfall_text, (
    "❌ Grenzfall-Antwort muss klar 'Nicht im Korpus' enthalten."
)

print("✅ Vertiefung-Selbstcheck bestanden!")
# Out:
# ✅ Vertiefung-Selbstcheck bestanden!

# %% [markdown]
# <p><font color='darkblue' size="4">
#  <b>Viz</b>
# </font></p>
#
# - [RAG-Pipeline](https://editor.p5js.org/ralf.bendig.rb/full/RrfB3nCwK)
# - [KI-Agent](https://editor.p5js.org/ralf.bendig.rb/full/u3Ee0jtFo)

# %% [markdown]
# # B | Dokumente zum Weiterlesen
# ---
#
# Ergänzende Artikel aus der Kurs-Dokumentation:
#
# - [RAG-Konzepte](https://ralf-42.github.io/Agenten/04-agenten-implementierung/kontext-wissen/rag-konzepte.html)
# - [Tool Use & Function Calling](https://ralf-42.github.io/Agenten/04-agenten-implementierung/entwurf/tool-use-function-calling.html)
# - [Context Engineering](https://ralf-42.github.io/Agenten/04-agenten-implementierung/kontext-wissen/context-engineering.html)
# - [Einsteiger ChromaDB](https://ralf-42.github.io/Agenten/05-frameworks/einsteiger-chromadb.html)
# - [Evaluation & Observability](https://ralf-42.github.io/Agenten/07-qualitaet-sicherheit/evaluation-observability.html)
