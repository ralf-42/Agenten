# %% [markdown]
# ## 💻 Übersicht der Notebook-Templates (5 Tage)
#
# | Tag | Kernthema | Notebook-Name | Schlüsselelemente im Template |
# | :--- | :--- | :--- | :--- |
# | **Tag 1** | Agent-Grundlagen & Tools | `01_Agent_Grundlagen.ipynb` | **Setup-Block:** Installationen, API-Key-Platzhalter, LangSmith Tracing-Initialisierung. **LangChain-Basis:** `init_chat_model()` Funktion und `@tool`-Decorator-Template. |
# | **Tag 2** | Chains & Structured Output | `02_LangChain_Chains.ipynb` | **Prompts:** `ChatPromptTemplate` Beispiele. **LCEL-Struktur:** Minimalbeispiel (`prompt \| llm`) und `RunnableParallel` Struktur. **Pydantic:** Leeres `PydanticBaseModel` Schema und `with_structured_output` Skeleton. |
# | **Tag 3** | Gedächtnis & RAG | `03_RAG_LangChain.ipynb` | **RAG-Setup:** Embedding-Initialisierung und `RecursiveCharacterTextSplitter` Setup. **Datenbank:** ChromaDB Initialisierung (mit Troubleshooting-Hinweis). **Chain:** RAG-Chain Platzhalter (`{context: retriever, question: passthrough} \| prompt \| llm`). |
# | **Tag 4** | Kontrolle mit LangGraph | `04_LangGraph_Basics.ipynb` | **State:** Imports und leeres `AgentState(TypedDict)`. **Struktur:** `StateGraph` Initialisierung, Node- und Edge-Platzhalter. **HITL:** Platzhalter für das `Human-in-the-Loop` (`interrupt()`) Pattern. |
# | **Tag 5** | Multi-Agent-Systeme | `05_MultiAgent_Projekt.ipynb` | **Basisskelett:** Das **vollständige, starke LangGraph Supervisor Basisskelett**. **TODOs:** Klare `TODO:`-Kommentare an den Stellen, die für das Supervisor-Routing und die Worker-Logik implementiert werden müssen. |
